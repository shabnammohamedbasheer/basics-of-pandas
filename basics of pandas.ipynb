# %%
import pandas as pd

# %%
df=pd.read_csv("amazon_reviews.csv")

# %%
df.head()
# Out:
#        Id   ProductId          UserId                ProfileName  \
# 0   59033  B002HQLY7S   AR89H8T4PVWSL                  rumbull01
# 1  514838  B007IVEP8C  A15VHPHU0V8GOH  Judith A. Weller "jw1917"
# 2  419751  B0029ZAOW8  A3CG7K9OQ5M0RI                   reviewer
# 3     870  B000VKYKTG  A1C1Y0S6QPBM4W                  R. Dzuris
# 4  282582  B001EO5WZ4  A2MERSI1KHYIQB     Kathy D. FERRELL "Kat"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                   NaN                     0.0    5.0  1320192000
# 1                   0.0                     0.0    1.0  1345766400
# 2                   2.0                     2.0    5.0  1278633600
# 3                   0.0                     0.0    5.0  1231286400
# 4                   0.0                     0.0    1.0  1325894400
#
#               Summary                                               Text
# 0      Awesome coffee  Purchasing this coffee was definatly worth it!...
# ...

# %%
df["Id"]
# Out:
# 0       59033
# 1      514838
# 2      419751
# 3         870
# 4      282582
#         ...
# 995     65930
# 996    465157
# 997    393049
# 998     79165
# 999    430883
# Name: Id, Length: 1000, dtype: int64

# %%
type(df["Id"])
# Out:
# pandas.core.series.Series

# %%
# id is of series class which says each single feature or a column in df returns a series or 1-D array

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[["ProductId","UserId"]]
# Out:
#       ProductId          UserId
# 0    B002HQLY7S   AR89H8T4PVWSL
# 1    B007IVEP8C  A15VHPHU0V8GOH
# 2    B0029ZAOW8  A3CG7K9OQ5M0RI
# 3    B000VKYKTG  A1C1Y0S6QPBM4W
# 4    B001EO5WZ4  A2MERSI1KHYIQB
# ..          ...             ...
# 995  B0007A0AQW  A2NJSEH07UD6M8
# 996  B0019H0YZ4   ARRVAYRLATRE5
# 997  B003VXL0V6  A2TIGI9VK33WPQ
# 998  B0046HCH5Y  A127NYPMASKWFS
# 999  B001EQ4ZTG  A2A2BPPJTYV4TU
#
# [1000 rows x 2 columns]

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                          int64
# ProductId                  object
# UserId                     object
# ProfileName                object
# HelpfulnessNumerator      float64
# HelpfulnessDenominator    float64
# Score                     float64
# Time                        int64
# Summary                    object
# Text                       object
# dtype: object

# %%
df["Text"].values
# Out:
# array(['Purchasing this coffee was definatly worth it! Not only is it not that expensive but it tastes wonderful! Although you get 50 I had to purchase another box because my husband and I liked it so much.',
#        "This has to be the worst product trying to pass itself off as caramel popcorn. I could taste no caramel or cinnamon. Just a bunch of watery sugar. Don't buy this product. Also it has a lot of unpopped kernels in it.",
#        "Can't rate this stuff highly enough, does as advertised, no let down as with sugar/caffeinated drinks.  There doesn't seem to be any addictive tendencies with 5-H-E which is nice.  I do not use this every day, great when driving to keep you alert behind the wheel.  Definitely the shizz.  Buy it.  Try it.",
#        'These where great couldnt stop eating them.<br />Lowest priced anywhere and will buy even more next time.<br />Cant say enough about these, they where shipped faster than what I paid to have shipped also.<br />Thank you so much.',
# ...

# %%
df['ProductId'].values
# Out:
# array(['B002HQLY7S', 'B007IVEP8C', 'B0029ZAOW8', 'B000VKYKTG',
#        'B001EO5WZ4', 'B0042GXR8A', 'B001SIXXWU', 'B001UUOP8C',
#        'B001SB0HNA', 'B00IUY', 'B000HDK0DC', 'B003V5HEXC', 'B000F4094I',
#        'BOOIHJ', 'B001E5E1LE', 'B001EO5KSS', 'B000ER6YO0', 'B000G6MBWI',
#        'B008JKU2CO', 'B00139E43Q', 'B000GFYRJE', 'B001BDDT8K',
#        'B000CQC05K', 'B000B8ZA60', 'B004U49QU2', 'B00271OPVU',
#        'B000UBD88A', 'B001ASCZS6', 'B005C3DTIK', 'B000V17MLS',
#        'B002Z08RIA', 'B0009ETA6W', 'B000VK8AVK', 'B0029O10P4',
#        'B0002HAB64', 'B004RBT8KG', 'B0049Z5OSK', 'B002QWP89S',
#        'B000M36L9E', 'B000ILILLQ', 'B0085YB426', 'B000N5Z5YI',
#        'B000FFIL92', 'B000BRWX0C', 'B000H227BG', 'B004ZY34NC',
#        'B003DKT8AC', 'B002QWP8H0', 'B000KV7ZGQ', 'B0050X8EK0',
#        'B001F653HS', 'B000KV7ZGQ', 'B006E8OGNY', 'B007PA32L2',
#        'B001NJI7GQ', 'B000NP30V8', 'B0014APFB4', 'B0001FQVMK',
#        'B000EHXWIQ', 'B000E4ALGK', 'B002ACQHC6', 'B003120Y4Q',
# ...

# %%
for i in df['ProductId'].values:
    if i[-1]=="A":
        print(i)
# Out:
# B0042GXR8A
# B001SB0HNA
# B000UBD88A
# B002Z08RIA
# B005K4Q1YA
# B003SBRQ0A
# B005K4Q1YA
# B000E65OQA
# B0099HD3YA
# B008EM51FA
# B001EO772A
# B001CWV4PA
# B000E46GFA
# B000SATIFA
# B000YDUZXA
# B001QGKF2A
# B0026KNQSA
# B001E5E3IA
# B000E46GFA
# B000SATIFA
# B0030GQHXA
# B003GVBN1A
# B0026LIO9A
# B005K4Q37A
# B00395DVJA
# B001ACMCNA
# B006N08SPA
# B001M08YZA
# B00028HN5A
# B001H05FMA
# B001T8I45A
# B000FSH3MA
# B002IEZJMA
# B000FL0A9A
# B006N3IE6A
# B002ZX1U9A
# B002GWH6MA
# B006N3IE6A
# B007F5MJMA
# B001181NBA
# B000KOQJ1A
# B000EDBQ6A
# B002ZX1U9A
# B003ZXE9QA
# B004OVWQDA
# B000F4ISFA
# B003B3OOPA
# B006N3IE6A
# B00286KM2A
# B004M8FXNA
# B003H7CSSA
# B008JKTH2A
# B0010BQB6A
# B001F0RJNA
# B007N04BZA
# B000I3UZJA
# B004OVWQDA

# %%
df.head()
# Out:
#        Id   ProductId          UserId                ProfileName  \
# 0   59033  B002HQLY7S   AR89H8T4PVWSL                  rumbull01
# 1  514838  B007IVEP8C  A15VHPHU0V8GOH  Judith A. Weller "jw1917"
# 2  419751  B0029ZAOW8  A3CG7K9OQ5M0RI                   reviewer
# 3     870  B000VKYKTG  A1C1Y0S6QPBM4W                  R. Dzuris
# 4  282582  B001EO5WZ4  A2MERSI1KHYIQB     Kathy D. FERRELL "Kat"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                   NaN                     0.0    5.0  1320192000
# 1                   0.0                     0.0    1.0  1345766400
# 2                   2.0                     2.0    5.0  1278633600
# 3                   0.0                     0.0    5.0  1231286400
# 4                   0.0                     0.0    1.0  1325894400
#
#               Summary                                               Text
# 0      Awesome coffee  Purchasing this coffee was definatly worth it!...
# ...

# %%
df.head(2)
# Out:
#        Id   ProductId          UserId                ProfileName  \
# 0   59033  B002HQLY7S   AR89H8T4PVWSL                  rumbull01
# 1  514838  B007IVEP8C  A15VHPHU0V8GOH  Judith A. Weller "jw1917"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                   NaN                     0.0    5.0  1320192000
# 1                   0.0                     0.0    1.0  1345766400
#
#             Summary                                               Text
# 0    Awesome coffee  Purchasing this coffee was definatly worth it!...
# 1  Like Sugar Syrup  This has to be the worst product trying to pas...

# %%
df["ProfileName"].value_counts()
# Out:
# Amazon Addict                   2
# Yarii                           2
# Holly K "Book addict"           2
# Zack Davisson                   2
# J. Taylor                       2
#                                ..
# Steven H. Dymond "sdymondpc"    1
# GLH                             1
# blancaJim                       1
# Julia                           1
# J. Bayless                      1
# Name: ProfileName, Length: 985, dtype: int64

# %%
df.describe()
# Out:
#                   Id  HelpfulnessNumerator  HelpfulnessDenominator  \
# count    1000.000000            999.000000              999.000000
# mean   287877.115000              1.852853                2.429429
# std    164630.847881              5.897366                7.275482
# min       518.000000              0.000000                0.000000
# 25%    147610.250000              0.000000                0.000000
# 50%    289888.000000              0.000000                1.000000
# 75%    430994.500000              2.000000                2.000000
# max    568044.000000             96.000000              134.000000
#
#             Score          Time
# count  998.000000  1.000000e+03
# mean     4.191383  1.294445e+09
# std      1.325790  4.914081e+07
# min      1.000000  1.068077e+09
# 25%      4.000000  1.267294e+09
# 50%      5.000000  1.307362e+09
# 75%      5.000000  1.332763e+09
# max      5.000000  1.351210e+09

# %%
df.isna().sum(axis=0)
# Out:
# Id                        0
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      1
# HelpfulnessDenominator    1
# Score                     2
# Time                      0
# Summary                   0
# Text                      0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.dropna(subset=["HelpfulnessDenominator"],inplace=True)

# %%
df["Score"]=df["Score"].fillna(0)

# %%
df.isna().sum()
# Out:
# Id                        0
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      1
# HelpfulnessDenominator    0
# Score                     0
# Time                      0
# Summary                   0
# Text                      0
# dtype: int64

# %%
df["HelpfulnessNumerator"]=df["HelpfulnessNumerator"].fillna(df["HelpfulnessNumerator"].mean())

# %%
df.isna().sum()
# Out:
# Id                        0
# ProductId                 0
# UserId                    0
# ProfileName               0
# HelpfulnessNumerator      0
# HelpfulnessDenominator    0
# Score                     0
# Time                      0
# Summary                   0
# Text                      0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                          int64
# ProductId                  object
# UserId                     object
# ProfileName                object
# HelpfulnessNumerator      float64
# HelpfulnessDenominator    float64
# Score                     float64
# Time                        int64
# Summary                    object
# Text                       object
# dtype: object

# %%
df["Score"].head()
# Out:
# 0    5.0
# 1    1.0
# 2    5.0
# 3    5.0
# 4    1.0
# Name: Score, dtype: float64

# %%
df["Score"]=df["Score"].astype("int")

# %%
df.dtypes
# Out:
# Id                          int64
# ProductId                  object
# UserId                     object
# ProfileName                object
# HelpfulnessNumerator      float64
# HelpfulnessDenominator    float64
# Score                       int32
# Time                        int64
# Summary                    object
# Text                       object
# dtype: object

# %%
df["Score_updated"]=df["Score"].astype("float")

# %%
df.head()
# Out:
#        Id   ProductId          UserId                ProfileName  \
# 0   59033  B002HQLY7S   AR89H8T4PVWSL                  rumbull01
# 1  514838  B007IVEP8C  A15VHPHU0V8GOH  Judith A. Weller "jw1917"
# 2  419751  B0029ZAOW8  A3CG7K9OQ5M0RI                   reviewer
# 3     870  B000VKYKTG  A1C1Y0S6QPBM4W                  R. Dzuris
# 4  282582  B001EO5WZ4  A2MERSI1KHYIQB     Kathy D. FERRELL "Kat"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0              1.850701                     0.0      5  1320192000
# 1              0.000000                     0.0      1  1345766400
# 2              2.000000                     2.0      5  1278633600
# 3              0.000000                     0.0      5  1231286400
# 4              0.000000                     0.0      1  1325894400
#
#               Summary                                               Text  \
# 0      Awesome coffee  Purchasing this coffee was definatly worth it!...
# ...

# %%
 df.drop("Score_updated",axis=1,inplace=True)

# %%
df.head()
# Out:
#        Id   ProductId          UserId                ProfileName  \
# 0   59033  B002HQLY7S   AR89H8T4PVWSL                  rumbull01
# 1  514838  B007IVEP8C  A15VHPHU0V8GOH  Judith A. Weller "jw1917"
# 2  419751  B0029ZAOW8  A3CG7K9OQ5M0RI                   reviewer
# 3     870  B000VKYKTG  A1C1Y0S6QPBM4W                  R. Dzuris
# 4  282582  B001EO5WZ4  A2MERSI1KHYIQB     Kathy D. FERRELL "Kat"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0              1.850701                     0.0      5  1320192000
# 1              0.000000                     0.0      1  1345766400
# 2              2.000000                     2.0      5  1278633600
# 3              0.000000                     0.0      5  1231286400
# 4              0.000000                     0.0      1  1325894400
#
#               Summary                                               Text
# 0      Awesome coffee  Purchasing this coffee was definatly worth it!...
# ...

# %% [markdown]
# - we can see the row removed

# %%
df[df["Score"]==5]
# Out:
#          Id   ProductId          UserId                      ProfileName  \
# 0     59033  B002HQLY7S   AR89H8T4PVWSL                        rumbull01
# 2    419751  B0029ZAOW8  A3CG7K9OQ5M0RI                         reviewer
# 3       870  B000VKYKTG  A1C1Y0S6QPBM4W                        R. Dzuris
# 7    211680  B001UUOP8C  A15GK1KULYHI12            BG in Chicago "Kiril"
# 8    463996  B001SB0HNA  A1KPALLWZ73M27                       BeagleGrin
# ..      ...         ...             ...                              ...
# 995   65930  B0007A0AQW  A2NJSEH07UD6M8                           Payton
# 996  465157  B0019H0YZ4   ARRVAYRLATRE5                               JK
# 997  393049  B003VXL0V6  A2TIGI9VK33WPQ                    hazeleyesjudi
# 998   79165  B0046HCH5Y  A127NYPMASKWFS  Axis "Freelance Media Designer"
# 999  430883  B001EQ4ZTG  A2A2BPPJTYV4TU                       J. Bayless
#
#      HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# ...

# %%
df.sort_values(by="Score",ascending=False)
# Out:
#          Id   ProductId          UserId  \
# 0     59033  B002HQLY7S   AR89H8T4PVWSL
# 597  137192  B001P05K7M  A16RND64P64QKA
# 599  516944  B000G1PAC6   AZ4T9C2CQ56G5
# 600  497165  B004E4EBMG  A2ADO5ATT47T5A
# 604   52246  B001EO5YXO  A15H8H0ZE3D28D
# ..      ...         ...             ...
# 594   48266  B004SRH2B6   A7ZGR5KW58S68
# 593  113170  B0030F70LO   AR0CBVTO8Q142
# 712  494663  B00176ICJC  A12VA1C3UFTB1J
# 16      936  B000ER6YO0  A13EBBWOMC0FUI
# 17   217041  B000G6MBWI  A1DMR4TXV10JBB
#
#                                           ProfileName  HelpfulnessNumerator  \
# 0                                           rumbull01              1.850701
# 597                                   Cheryl Schwartz              0.000000
# 599                                           Matthew             29.000000
# 600                              S. Urwin "red runts"              0.000000
# 604                                    Patricia Davis              0.000000
# ...

# %%
def count_length(x):
    return len(x)

# %%
df["Text"].apply(count_length)
# Out:
# 0       198
# 1       215
# 2       305
# 3       228
# 4       246
#        ...
# 995     345
# 996    1062
# 997     238
# 998     504
# 999     109
# Name: Text, Length: 999, dtype: int64

# %%
df.groupby(["UserId"])["Score"].max()
# Out:
# UserId
# #oc-RXFX0AFFBDSJN    5
# A100WO06OQR8BQ       5
# A104M4DKQ96IT0       1
# A1088P38KHFI9B       5
# A10G8ZYR2RVVAE       1
#                     ..
# AZDYF8AXM2GYG        5
# AZLNNFQ88C9E7        1
# AZPOFLFAWXON         5
# AZQZ45Q9U1GNS        5
# AZR55JSEMWB76        4
# Name: Score, Length: 990, dtype: int32

# %%
df.groupby(["UserId"])["Score"].count()
# Out:
# UserId
# #oc-RXFX0AFFBDSJN    1
# A100WO06OQR8BQ       1
# A104M4DKQ96IT0       1
# A1088P38KHFI9B       1
# A10G8ZYR2RVVAE       1
#                     ..
# AZDYF8AXM2GYG        1
# AZLNNFQ88C9E7        1
# AZPOFLFAWXON         1
# AZQZ45Q9U1GNS        1
# AZR55JSEMWB76        1
# Name: Score, Length: 990, dtype: int64

# %%
df.groupby(["UserId"])["Score"].count().reset_index()
# Out:
#                 UserId  Score
# 0    #oc-RXFX0AFFBDSJN      1
# 1       A100WO06OQR8BQ      1
# 2       A104M4DKQ96IT0      1
# 3       A1088P38KHFI9B      1
# 4       A10G8ZYR2RVVAE      1
# ..                 ...    ...
# 985      AZDYF8AXM2GYG      1
# 986      AZLNNFQ88C9E7      1
# 987       AZPOFLFAWXON      1
# 988      AZQZ45Q9U1GNS      1
# 989      AZR55JSEMWB76      1
#
# [990 rows x 2 columns]

# %%
df["Score"].value_counts()
# Out:
# 5    648
# 4    136
# 1     96
# 3     64
# 2     53
# 0      2
# Name: Score, dtype: int64

# %%
df["Score"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %%
df["Score"].value_counts().plot(kind="line")
# Out:
# <Axes: >

# %%
df["Score"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='Score'>
